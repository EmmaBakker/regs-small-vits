# %%
import os
import sys

input_dir = "/kaggle/input/dino-models"

work_dir = "/kaggle/working/dino-models"

# !cp -r "$input_dir" "$work_dir"

sys.path.append(work_dir)

# %%
requirements_path = os.path.join(work_dir, "requirements.txt")
# !pip install -r "$requirements_path"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.2 MB/s eta 0:00:00
# WARNING: Ignoring version 22.4 of catalyst since it has invalid metadata:
# Requested catalyst from https://files.pythonhosted.org/packages/05/09/36a4acd1c3112f2e2da74f4340778100a205ecb59166be00dc6287f3364f/catalyst-22.4-py2.py3-none-any.whl (from -r /kaggle/working/tryout5/requirements.txt (line 6)) has invalid metadata: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     scikit-image (<0.19.0>=0.16.1) ; extra == 'all'
#                  ~~~~~~~~^
# Please use pip<24.1 if you need to use this version.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 3.2 MB/s eta 0:00:00
# WARNING: Ignoring version 22.2.1 of catalyst since it has invalid metadata:
# ...

# %%
from custom_datasets import Dataset
import torchvision

# %%
import os

voc_dir = os.path.join(work_dir, "datasets", "VOC2007")
os.makedirs(voc_dir, exist_ok=True)  # create the /datasets/VOC2007 folder if it doesn't exist

# %%
dataset = torchvision.datasets.VOCDetection(
    root=voc_dir,
    year="2007",
    image_set="trainval",
    download=True
)

print(f"Number of images in the trainval set: {len(dataset)}")
# Out:
# ...
# 100%|██████████| 460M/460M [00:22<00:00, 20.8MB/s]
# Extracting /kaggle/working/tryout5/datasets/VOC2007/VOCtrainval_06-Nov-2007.tar to /kaggle/working/tryout5/datasets/VOC2007
# Number of images in the trainval set: 5011

# %%
# Download model checkpoints directly into the existing "dinov2/models" folder
# !wget -q https://dl.fbaipublicfiles.com/dinov2/dinov2_vitl14/dinov2_vitl14_pretrain.pth \
    -O "$work_dir/dinov2/models/dinov2_vitl14_pretrain.pth"

# !wget -q https://dl.fbaipublicfiles.com/dinov2/dinov2_vitl14/dinov2_vitl14_reg4_pretrain.pth \
    -O "$work_dir/dinov2/models/dinov2_vitl14_reg4_pretrain.pth"

# !ls -l "$work_dir/dinov2/models"
# Out:
# total 2378144
# -rw-r--r-- 1 root root 1217586395 Apr 13  2023 dinov2_vitl14_pretrain.pth
# -rw-r--r-- 1 root root 1217607321 Oct 27  2023 dinov2_vitl14_reg4_pretrain.pth
# -rw-r--r-- 1 root root       1486 Jan 28 15:35 __init__.py
# -rw-r--r-- 1 root root      15039 Jan 28 15:35 vision_transformer.py

# %%
# %cd /kaggle/working/dino-models

# !python main_lost.py \
    --arch dinov2_vitl14 \
    --dataset VOC07 \
    --set trainval \
    --which_features k \
    --output_dir "/kaggle/working/outputs_dino_without_registers"
# Out:
# /kaggle/working/tryout5
# /kaggle/working/tryout5/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /kaggle/working/tryout5/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /kaggle/working/tryout5/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# ==> Building DINOv2 ViT-L/14 (no registers)
# Loading checkpoint from dinov2/models/dinov2_vitl14_pretrain.pth ...
# ...

# %%
# %cd /kaggle/working/dino-models

# !python main_lost.py \
    --arch dinov2_vitl14_reg \
    --dataset VOC07 \
    --set trainval \
    --which_features k \
    --output_dir "/kaggle/working/outputs_dino_with_registers"
# Out:
# /kaggle/working/tryout5
# /kaggle/working/tryout5/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /kaggle/working/tryout5/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /kaggle/working/tryout5/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# ==> Building DINOv2 ViT-L/14 (with registers)
# Loading checkpoint from dinov2/models/dinov2_vitl14_reg4_pretrain.pth ...
# ...
