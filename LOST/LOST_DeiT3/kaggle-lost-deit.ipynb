# %%
import os
import sys

input_dir = "/kaggle/input/deit-models2"

work_dir = "/kaggle/working/deit-models2"

# !cp -r "$input_dir" "$work_dir"

sys.path.append(work_dir)

# %%
requirements_path = os.path.join(work_dir, "requirements.txt")
# !pip install -r "$requirements_path"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.3 MB/s eta 0:00:00
# WARNING: Ignoring version 22.4 of catalyst since it has invalid metadata:
# Requested catalyst from https://files.pythonhosted.org/packages/05/09/36a4acd1c3112f2e2da74f4340778100a205ecb59166be00dc6287f3364f/catalyst-22.4-py2.py3-none-any.whl (from -r /kaggle/working/deit-models2/requirements.txt (line 6)) has invalid metadata: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     scikit-image (<0.19.0>=0.16.1) ; extra == 'all'
#                  ~~~~~~~~^
# Please use pip<24.1 if you need to use this version.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 3.7 MB/s eta 0:00:00
# WARNING: Ignoring version 22.2.1 of catalyst since it has invalid metadata:
# ...

# %%
from custom_datasets import VOC2007Dataset
import torchvision

# %%
import os

voc_dir = os.path.join(work_dir, "datasets", "VOC2007")
os.makedirs(voc_dir, exist_ok=True)  # create the /datasets/VOC2007 folder if it doesn't exist

# %%
dataset = torchvision.datasets.VOCDetection(
    root=voc_dir,
    year="2007",
    image_set="trainval",
    download=True
)

print(f"Number of images in the trainval set: {len(dataset)}")
# Out:
# ...
# 100%|██████████| 460M/460M [00:44<00:00, 10.3MB/s]
# Extracting /kaggle/working/deit-models2/datasets/VOC2007/VOCtrainval_06-Nov-2007.tar to /kaggle/working/deit-models2/datasets/VOC2007
# Number of images in the trainval set: 5011

# %%
# !ls /kaggle/working/deit-models2/datasets/VOC2007
# Out:
# VOCdevkit  VOCtrainval_06-Nov-2007.tar

# %%
# !python main_lost.py \
    --voc_root /kaggle/working/deit-models2/datasets/VOC2007 \
    --voc_set trainval \
    --checkpoint_path /kaggle/working/deit-models2/checkpoint299_source.pth \
    --model_type source
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.10/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /kaggle/working/deit-models2/models_v2_reg.py:362: UserWarning: Overwriting deit_tiny_patch16_LS in registry with models_v2_reg.deit_tiny_patch16_LS. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   def deit_tiny_patch16_LS(pretrained=False, img_size=224, pretrained_21k = False,   **kwargs):
# ...

# %%
# !python main_lost.py \
    --voc_root /kaggle/working/deit-models2/datasets/VOC2007 \
    --voc_set trainval \
    --checkpoint_path /kaggle/working/deit-models2/checkpoint299_reg.pth \
    --model_type reg
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.10/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /kaggle/working/deit-models2/models_v2_reg.py:362: UserWarning: Overwriting deit_tiny_patch16_LS in registry with models_v2_reg.deit_tiny_patch16_LS. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   def deit_tiny_patch16_LS(pretrained=False, img_size=224, pretrained_21k = False,   **kwargs):
# ...
