# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3
# Out:
# /content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3')

# %%
# !pip install -r '/content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/requirements.txt'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# WARNING: Ignoring version 22.4 of catalyst since it has invalid metadata:
# Requested catalyst from https://files.pythonhosted.org/packages/05/09/36a4acd1c3112f2e2da74f4340778100a205ecb59166be00dc6287f3364f/catalyst-22.4-py2.py3-none-any.whl (from -r /content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/requirements.txt (line 6)) has invalid metadata: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     scikit-image (<0.19.0>=0.16.1) ; extra == 'all'
#                  ~~~~~~~~^
# Please use pip<24.1 if you need to use this version.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 4.8 MB/s eta 0:00:00
# WARNING: Ignoring version 22.2.1 of catalyst since it has invalid metadata:
# ...

# %%
from custom_datasets import VOC2007Dataset

# %%
import torchvision

dataset = torchvision.datasets.VOCDetection(
    root="/content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/datasets/VOC2007",
    year="2007",
    image_set="trainval",
    download=True
)
print(f"Number of images in the trainval set: {len(dataset)}")
# Out:
# ...
# 100%|██████████| 460M/460M [00:23<00:00, 19.8MB/s]
# Extracting /content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/datasets/VOC2007/VOCtrainval_06-Nov-2007.tar to /content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/datasets/VOC2007
# Number of images in the trainval set: 5011

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/datasets/VOC2007"
# Out:
# VOCdevkit  VOCtrainval_06-Nov-2007.tar

# %%
# !python main_lost.py \
    --voc_root "/content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/datasets/VOC2007" \
    --voc_set trainval \
    --checkpoint_path "/content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/checkpoint299_source.pth" \
    --model_type source
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/models_v2_reg.py:361: UserWarning: Overwriting deit_tiny_patch16_LS in registry with models_v2_reg.deit_tiny_patch16_LS. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# ...

# %%
# !python main_lost.py \
    --voc_root "/content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/datasets/VOC2007" \
    --voc_set trainval \
    --checkpoint_path "/content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/checkpoint299_reg.pth" \
    --model_type reg
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /content/drive/My Drive/Colab Notebooks/FACT/LOST_DeiT3/models_v2_reg.py:361: UserWarning: Overwriting deit_tiny_patch16_LS in registry with models_v2_reg.deit_tiny_patch16_LS. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   @register_model
# ...
